# %% [markdown]
# <a href="https://colab.research.google.com/github/Suman-Vasireddy/SummerSchool-Assignment/blob/Suman_PH20B012/Assignment1_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Question 1

# %%
import numpy as np
y=np.random.randint(0,2,size=100)
y_cap=np.random.rand(100)

# %%
def O(a,b):
    if len(a)==len(b):
        z=-1/len(a)*np.sum(a*np.log2(b)+(1-a)*np.log2(1-b))
        return z
    else: print("Error:Both arrays should be of same dimesnion")

O(y,y_cap)
# Out:
# 1.6438906679762213

# %% [markdown]
# ### Question 2

# %%
class Sum_Constituents:
    
    
    def find_pair(self,array,target):
        output_dict={}
        k=1
        for i in range(len(array)):
            for j in range(len(array)):
                if array[i]+array[j]==target:
                    output_dict[k]=[i,j]
                    k=k+1
        return output_dict

# %%
# Given example
arr1=[10,20,10,40,50,60,70]
t1=50
ans=Sum_Constituents()
ans.find_pair(arr1,t1)
# Out:
# {1: [0, 3], 2: [2, 3], 3: [3, 0], 4: [3, 2]}
