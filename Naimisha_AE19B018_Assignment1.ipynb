# %% [markdown]
# <a href="https://colab.research.google.com/github/naimscodes/SummerSchool-Assignment/blob/main/Naimisha_AE19B018_Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **QUESTION - 1**
# *Cross Entropy Calculation*

# %%
import numpy as np
n=100
y_hat = np.random.rand(100)
y = np.random.randint(0,2,100)
sumation = y*np.log2(y_hat)+(1-y)*np.log2(1-y_hat)
cross_entropy = -1*np.sum(sumation)/n
print(cross_entropy)

# %% [markdown]
# ## **QUESTION - 2**
# *Finding pair of elements whose sum equal to a target using class*

# %%
class Target:
  # class variables
  solutions = {}

  def __init__(self, target, num):
    self.target = target
    self.num = num
    k = 1
    for i in range(0,len(num)):                   
      for j in range(0,len(num)):
        if (self.target == self.num[i]+self.num[j]):        
           self.solutions[k] = [i,j]                  
           k=k+1

    if (k == 1 ):                
      print("No solutions exist")
    else :
      print(self.solutions)
